# %% [markdown]
# # Netflix TV Shows and Movies

# %% [markdown]
# This notebook will focus on cleaning and preparing a Netflix dataset from Kaggle for analysis and visualization.
#
#
# ###  Objectives:
# - Explore the structure and contents of the raw dataset
# - Identify and handle missing, duplicate, or inconsistent data
# - Standardize columns such as release date, duration, and genres
# - Output a clean, structured dataset for use in Tableau
#
# ###  Dataset:
# - Source: [Netflix Titles Dataset from Kaggle](https://www.kaggle.com/datasets/shivamb/netflix-shows)
# - File: `netflix_titles.csv`
#
# ---
#
#  By the end of this notebook, we will generate a clean CSV file (`netflix_cleaned.csv`) ready for visual exploration in Tableau.

# %%
import pandas as pd

# %% [markdown]
# # Read the data

# %%
data=pd.read_csv('netflix_titles.csv')
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# # Rename and initial exploration

# %%
df=data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# # Clean the data

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# drop the ten rows from 'date_added'

df = df.dropna(subset=['date_added'])
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# duration column

df['duration'].value_counts().head(10)
# Out:
# duration
# 1 Season     1793
# 2 Seasons     421
# 3 Seasons     198
# 90 min        152
# 94 min        146
# 97 min        146
# 93 min        146
# 91 min        144
# 95 min        137
# 96 min        130
# Name: count, dtype: int64

# %%
# split the column to extract and determine if the column has minutes or seasons

df[['duration_value', 'duration_unit']] = df['duration'].str.extract(r'(\d+)\s+(\w+)')

# %%
df['duration_value'] = pd.to_numeric(df['duration_value'], errors='coerce')

# %%
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  duration_value  \
# 0  As her father nears the end of his life, filmm...            90.0
# 1  After crossing paths at a party, a Cape Town t...             2.0
# 2  To protect his family from a powerful drug lor...             1.0
#
#   duration_unit
# 0           min
# 1       Seasons
# 2        Season

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'duration_value', 'duration_unit'],
#       dtype='object')

# %%
# drop columns that would be irrelevant in visualizations or that are not needed

df.drop(['show_id','duration'], axis=1, inplace=True)
df.head(3)
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water              NaN
# 2  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating  \
# 0  September 25, 2021          2020  PG-13
# 1  September 24, 2021          2021  TV-MA
# 2  September 24, 2021          2021  TV-MA
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  duration_value  \
# 0  As her father nears the end of his life, filmm...            90.0
# 1  After crossing paths at a party, a Cape Town t...             2.0
# 2  To protect his family from a powerful drug lor...             1.0
#
#   duration_unit
# 0           min
# 1       Seasons
# 2        Season

# %%
# strip white spaces

df.columns = df.columns.str.strip()
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating  \
# 0  September 25, 2021          2020  PG-13
# 1  September 24, 2021          2021  TV-MA
# 2  September 24, 2021          2021  TV-MA
# 3  September 24, 2021          2021  TV-MA
# 4  September 24, 2021          2021  TV-MA
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  duration_value  \
# 0  As her father nears the end of his life, filmm...            90.0
# 1  After crossing paths at a party, a Cape Town t...             2.0
# 2  To protect his family from a powerful drug lor...             1.0
# 3  Feuds, flirtations and toilet talk go down amo...             1.0
# 4  In a city of coaching centers known to train I...             2.0
#
#   duration_unit
# 0           min
# 1       Seasons
# 2        Season
# 3        Season
# 4       Seasons

# %%
# check if there are any whitespaces left

[col for col  in df.columns
if col != col.strip()]
# Out:
# []

# %%
df.isnull().sum()
# Out:
# type                 0
# title                0
# director          2624
# cast               825
# country            830
# date_added           0
# release_year         0
# rating               4
# listed_in            0
# description          0
# duration_value       3
# duration_unit        3
# dtype: int64

# %%
# explore the 'director' column and take necessary steps

df[df['director'].isnull()]['type'].value_counts()
# Out:
# type
# TV Show    2436
# Movie       188
# Name: count, dtype: int64

# %%
df[df['director'].isnull()]['country'].value_counts()
# Out:
# country
# United States                                    764
# United Kingdom                                   206
# Japan                                            159
# South Korea                                      150
# India                                             82
#                                                 ...
# Chile, Italy                                       1
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 188, dtype: int64

# %% [markdown]
# Most of the empty rows for 'director' seem to come from TV Shows

# %%
# fill the empty rows for 'director' column with 'unknown'

df['director'] = df['director'].fillna('Unknown')

# %%
# check 'director' for inconsistent formats

df['director'].value_counts().head(20)
# Out:
# director
# Unknown                   2624
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Jay Chapman                 12
# Youssef Chahine             12
# Martin Scorsese             12
# Steven Spielberg            11
# Don Michael Paul            10
# David Dhawan                 9
# Yılmaz Erdoğan               8
# Quentin Tarantino            8
# Lance Bangs                  8
# Shannon Hartman              8
# Troy Miller                  8
# Kunle Afolayan               8
# Johnnie To                   8
# Name: count, dtype: int64

# %%
sorted(df['director'].unique())
# Out:
# ['A. L. Vijay',
#  'A. Raajdheep',
#  'A. Salaam',
#  'A.R. Murugadoss',
#  'Aadish Keluskar',
#  'Aamir Bashir',
#  'Aamir Khan',
#  'Aanand Rai',
#  'Aaron Burns',
#  'Aaron Hancox, Michael McNamara',
#  'Aaron Hann, Mario Miscione',
#  'Aaron Lieber',
#  'Aaron Nee, Adam Nee',
#  'Aaron Sorkin',
#  'Aaron Woodley',
#  'Aatmaram Dharne',
#  'Abba T. Makama',
#  'Abbas Alibhai Burmawalla, Mastan Alibhai Burmawalla',
#  'Abbas Mustan',
#  'Abbas Tyrewala',
#  'Abby Epstein',
#  'Abdellatif Kechiche',
#  'Abdul Aziz Hashad',
#  'Abdulaziz Alshlahei',
#  'Abel Ferrara',
#  'Abhay Chopra',
#  'Abhijeet Deshpande',
#  'Abhijit Kokate, Srivinay Salian',
#  'Abhijit Panse',
#  'Abhinay Deo',
#  'Abhishek Chaubey',
#  'Abhishek Kapoor',
#  'Abhishek Saxena',
#  'Abhishek Sharma',
#  'Abhishek Varman',
#  'Abir Sengupta',
#  'Abu Bakr Shawky',
#  'Achille Brice',
#  'Adam Alleca',
#  'Adam B. Stein, Zach Lipovsky',
#  'Adam Bhala Lough',
#  'Adam Bolt',
#  'Adam Collins, Luke Radford',
#  'Adam Davis, Jerry Kolber, Trey Nelson, Erich Sturm',
#  'Adam Del Giudice',
#  'Adam Deyoe',
#  'Adam Dubin',
#  'Adam Leon',
#  'Adam MacDonald',
#  'Adam Marino',
#  'Adam McKay',
#  'Adam Nimoy',
#  'Adam Randall',
#  'Adam Salky',
#  'Adam Shankman',
#  'Adam Sjöberg',
#  'Adam Smith',
#  'Adam Wingard',
#  'Adam Wood',
#  'Adarsh Eshwarappa',
#  'Adekunle Nodash Adejuyigbe',
#  'Adele K. Thomas, Richard Bailey',
#  'Adisorn Tresirikasem',
#  'Aditya Kripalani',
#  'Aditya Sarpotdar',
#  'Aditya Vikram Sengupta',
#  'Adrian Murray',
#  'Adrian Teh',
#  'Adriana Trigiani',
#  'Adriano Rudiman',
#  'Adrien Lagier, Ousmane Ly',
#  'Adrián García Bogliano',
#  'Advait Chandan',
#  'Adze Ugah',
#  'Afia Nathaniel',
#  'Afonso Poyart',
#  'Agasyah Karim, Khalid Kashogi',
#  'Agnidev Chatterjee',
#  'Agustí Villaronga',
#  'Ah Loong',
#  'Ahishor Solomon',
#  'Ahmad El-Badri',
#  'Ahmad Samir Farag',
#  'Ahmed Al-Badry',
#  'Ahmed El Gendy',
#  'Ahmed Medhat',
#  'Ahmed Nader Galal',
#  'Ahmed Saleh',
#  'Ahmed Siddiqui',
#  'Ahmed Yousry, Hazem Fouda',
#  'Ahmed Zain',
#  'Ahmed Zein',
#  'Ahmet Katıksız',
#  'Ahn Byoung-wook',
#  'Ahsan Rahim',
#  'Aijaz Khan',
#  'Ainsley Gardiner, Briar Grace-Smith',
#  'Aitor Arregi, Jon Garaño',
#  'Aitor Arregi, Jon Garaño, Jose Mari Goenaga',
#  'Ajay Bahl',
#  'Ajay Bhuyan, Kunal Kohli',
#  'Ajay Phansekar',
#  'Ajithkumar',
#  'Akashdeep',
#  'Akay Mason, Abosi Ogba',
#  'Akhigbe Ilozobhie',
#  'Akhil Paul, Anas Khan',
#  'Akin Omotoso',
#  'Akira Saitoh',
#  'Akiva Goldsman',
#  'Akiva Schaffer',
#  'Akiyuki Shinbo, Nobuyuki Takeuchi',
#  'Akram Farouk',
#  'Akshay Akkineni',
#  'Akshay Sanjeev Chavan, Sumit Das',
#  'Al Campbell, Alice Mathias',
#  'Alaa Eddine Aljem',
#  'Alain Brunard',
#  'Alain Darborg',
#  'Alain Desrochers',
#  'Alan Alda',
#  'Alan J. Pakula',
#  'Alan Parker',
#  'Alan Rickman',
#  'Alan Yang',
#  'Alankrita Shrivastava',
#  'Alastair Fothergill',
#  'Alastair Fothergill, Jonnie Hughes, Keith Scholey',
#  'Albert Hughes, Allen Hughes',
#  'Albert Sharpe',
#  'Alberto Arnaut Estrada',
#  'Alberto Rodríguez',
#  'Alejandra Márquez Abella',
#  'Alejandro Agresti',
#  'Alejandro De Grazia, Juan Stadler',
#  'Alejandro Doria',
#  'Alejandro Fernández Almendras',
#  'Alejandro G. Iñárritu',
#  'Alejandro Hartmann',
#  'Alejandro Lozano',
#  'Alejandro Montiel',
#  'Alejandro Ruax, Ramiro Martínez',
#  'Aleksey German',
#  'Aleksey Tsitsilin',
#  'Alessandra de Rossi',
#  'Alessandro Angulo',
#  'Alessandro Pepe',
#  'Alessio Cremonini',
#  'Alethea Jones',
#  'Alex Burunova',
#  'Alex Coletti',
#  'Alex Díaz',
#  'Alex Díaz, Marcos Bucay',
#  'Alex Garland',
#  'Alex Gibney',
#  'Alex Holmes',
#  'Alex Infascelli',
#  'Alex Israel',
#  'Alex Law',
#  'Alex Lehmann',
#  'Alex Merkin',
#  'Alex Parkinson, Richard da Costa',
#  'Alex Proyas',
#  'Alex Ranarivelo',
#  'Alex Richanbach',
#  'Alex Smith, Andrew J. Smith',
#  'Alex Stapleton',
#  'Alex Timbers',
#  'Alex Timbers, Sam Wrench',
#  'Alex Winter',
#  'Alex Woo, Stanley Moore',
#  'Alex Zamm',
#  'Alexandra Dean',
#  'Alexandre Aja',
#  'Alexandre Avancini',
#  'Alexandre Espigares',
#  'Alexandre Heboyan, Benoît Philippon',
#  'Alexandre Reinecke',
#  'Alexandros Avranas',
#  'Alexis Almström',
#  'Alexis Morante',
#  'Alexx Media',
#  'Alfons Adetuyi',
#  'Alfonso Arau',
#  'Alfonso Cortés-Cavanillas',
#  'Alfonso Cuarón',
#  'Alfonso Rodríguez',
#  'Alfonso Serrano Maturino',
#  'Ali Bin Matar, Ibrahim Bin Mohamed',
#  'Ali F. Mostafa',
#  'Ali Kalthami, Meshal Aljaser, Faris Godus, Mohamed al Salman, Faisal al Amer',
#  'Ali Ragab',
#  'Ali Samadi Ahadi',
#  'Ali Scher',
#  'Ali Tabrizi',
#  'Ali Taner Baltacı',
#  'Ali Taner Baltacı, Cem Yılmaz',
#  'Ali Yorgancıoğlu',
#  'Alice Filippi',
#  'Alice Rohrwacher',
#  'Alice Waddington',
#  'Alice Wu',
#  'Alik Sakharov',
#  'Alina Teodorescu',
#  'Alison E. Rose',
#  'Alison Klayman',
#  'Alison MacLean',
#  'Alistair Legrand',
#  'Allan Ungar',
#  'Allen Coulter',
#  'Ally Pankiw',
#  "Alma Har'el",
#  'Almudena Carracedo, Robert Bahar',
#  'Almunsif Alsuwaisi',
#  'Alo Sarkar',
#  'Alphonso J. Wesson',
#  'Alê Abreu',
#  'Amaan Khan',
#  'Amal Neerad',
#  'Amanda Micheli',
#  'Amanda Raymond',
#  'Amar Gupte',
#  'Amar Kaushik',
#  'Amara Cash',
#  'Amardeep Singh Gill',
#  'Amarjit Virdi',
#  'Amarpreet G S Chabbra',
#  'Amber Tamblyn',
#  'Amin Dora',
#  'Amir Mohiuddin',
#  'Amit Barot',
#  'Amit Rai',
#  'Amit Roy',
#  'Amit Saxena',
#  'Amitabha Singh',
#  'Amitava Bhattacharya',
#  'Amitoj Mann',
#  'Amman Abbasi',
#  'Amol Palekar',
#  'Amr Arafa',
#  'Amr Salama',
#  'Amro Salah',
#  'Amshan Kumar',
#  'Amy Poehler',
#  'Amy Rice',
#  'Amy Schumer',
#  'Amy Segal',
#  'Ana Kokkinos',
#  'Ana Lily Amirpour',
#  'Ana Quiroga',
#  'Anand Kamalakar',
#  'Anand Ravichandran',
#  'Anand Tiwari',
#  'Anand Tucker',
#  'Ananda Krishnan',
#  'Anant Balani',
#  'Ananth Narayan Mahadevan',
#  'Andaç Haznedaroğlu',
#  'Anders Falck, Stinus Morell Vithner',
#  'Anders Sømme Hammer, Marius Arnesen, Klaus Erik Okstad, Olav Njaastad',
#  'Andibachtiar Yusuf',
#  'Andrea Arnold',
#  'Andrea Molaioli',
#  'Andreas Johnsen',
#  'Andreas Pichler',
#  'Andreas Prochaska',
#  'Andres Clariond',
#  'Andrew Bergman',
#  'Andrew Bujalski',
#  'Andrew C. Erin',
#  'Andrew Davis',
#  'Andrew Dean',
#  'Andrew Dominik',
#  'Andrew Douglas',
#  'Andrew Duncan, Ken Cunningham',
#  'Andrew Fleming',
#  'Andrew Goth',
#  'Andrew Jenks',
#  'Andrew Lau Wai-Keung',
#  'Andrew Lau Wai-Keung, Andrew Loo',
#  'Andrew Lau Wai-keung, Alan Mak',
#  'Andrew Nackman',
#  'Andrew Niccol',
#  'Andrew Renzi',
#  'Andrew Sandler',
#  'Andrew Slater',
#  'Andrew Stanton',
#  'Andrew Tan, Michael Goguen',
#  'Andrew Tan, Stephen Murray',
#  'Andrew Wessels',
#  'Andrucha Waddington, Pedro Waddington',
#  'Andrzej Bartkowiak',
#  "André D'Elia",
#  'André Odendaal, Johan Vorster',
#  'André Øvredal',
#  'Andrés Couturier',
#  'Andrés Feddersen',
#  'Andy Caballero, Diego Corsini',
#  'Andy Capper',
#  'Andy Devonshire',
#  'Andy Fickman',
#  'Andy Goddard',
#  'Andy Serkis',
#  'Andy Tennant',
#  'Anees Bazmee',
#  'Ang Lee',
#  'Ange Basterga, Nicolas Lopez',
#  'Angel Kristi Williams',
#  'Angelina Jolie',
#  'Angga Dwimas Sasongko',
#  'Anggy Umbara',
#  'Angshuman Ghosh',
#  'Aniedi Anwah',
#  'Anik Datta',
#  'Anil Sharma',
#  'Anil Thomas',
#  'Anil V. Kumar, Anurag Basu',
#  'Anindya Chatterjee',
#  'Anirban Majumder',
#  'Aniruddha Roy Chowdhury',
#  'Anissa Bonnefont',
#  'Anita Barbosa',
#  'Anita Udeep',
#  'Anjali Nayar',
#  'Anjum Shahzad',
#  'Ann Deborah Fishman',
#  'Anna Boden, Ryan Fleck',
#  'Anna Elizabeth James',
#  'Anna Stone',
#  'Anna Wieczur-Bluszcz',
#  'Anne Fletcher',
#  'Anne Fontaine',
#  'Anoop Sathyan',
#  'Anthony Abrams, Adam Larson Broder',
#  'Anthony Bell',
#  'Anthony Byrne',
#  'Anthony Caronna, Alexander Smith',
#  'Anthony Chan',
#  "Anthony D'Souza",
#  'Anthony Giordano',
#  'Anthony Lucero',
#  'Anthony Mandler',
#  'Anthony Minghella',
#  'Anthony Pierce',
#  'Anthony Russo, Joe Russo',
#  'Anthony Scott Burns',
#  'Anthony Scott Burns, Nicholas McCarthy, Adam Egypt Mortimer, Gary Shore, Kevin Smith, Sarah Adina Smith, Scott Stewart, Kevin Kolsch, Dennis Widmyer',
#  'Anthony Wonke',
#  'Antoine Bardou-Jacquet',
#  'Antoine Fuqua',
#  'Antoinette Jadaone',
#  'Anton Corbijn',
#  'Antoni Krauze',
#  'Antonin Baudry',
#  'Antonio Campos',
#  'Antonio Chavarrías',
#  'Antonio Díaz',
#  'Antonio Morabito',
#  'Antonio Serrano',
#  'Anu Menon',
#  'Anubhav Sinha',
#  'Anurag Basu',
#  'Anurag Kashyap',
#  'Anurag Kashyap, Dibakar Banerjee, Karan Johar, Zoya Akhtar',
#  'Anurag Singh',
#  'Anuranjan Premji',
#  'Anurin Nwunembom',
#  'Anurin Nwunembom, Musing Derrick',
#  'Anusha Rizvi, Mahmood Farooqui',
#  'Anvita Dutt',
#  'Apoorva Lakhia',
#  'Appie Boudellah, Aram van de Rest',
#  'April Mullen',
#  'Apurva Dhar Badgaiyann',
#  'Arati Kadav',
#  'Archie Borders',
#  'Archie Hekagery',
#  'Ari Folman',
#  'Ari Levinson',
#  'Ari Sandel',
#  'Ariel Boles',
#  'Ariel Vromen',
#  'Arjun Gourisaria, Moinak Biswas',
#  'Arjun Jandyala',
#  'Armando Iannucci',
#  'Arnab Chaudhuri',
#  'Arne Birkenstock',
#  'Arnon Manor, Timothy Ware-Hill',
#  'Arpan Sarkar, Shyamal Chaulia',
#  'Arthur Allan Seidelman',
#  'Arthur Muhammad',
#  'Arthur Penn',
#  'Arun Chidambaram',
#  'Arun Vaidyanathan',
#  'Aruna Raje',
#  'Asghar Farhadi',
#  'Ash Brannon, Chris Buck',
#  'Ashim Ahluwalia',
#  'Ashish R. Mohan',
#  'Ashish R. Shukla',
#  'Ashok Nanda',
#  'Ashraf Fayeq',
#  'Ashu Trikha',
#  'Ashutosh Gowariker',
#  'Ashwin Saravanan',
#  'Ashwiny Iyer Tiwari',
#  'Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket Chaudhary',
#  'Asif Kapadia',
#  'Asim Abbasi',
#  'Asim Raza',
#  'Asit Mohapatra, Shyamal Chaulia',
#  'Asri Bendacha',
#  'Atanu Ghosh',
#  'Atanu Mukherjee',
#  'Atharv Baluja',
#  'Athiyan Athirai',
#  'Atlee Kumar',
#  'Atom Egoyan',
#  'Atsajun Sattakovit',
#  'Atsuko Ishizuka',
#  'Attila Till',
#  'Atul Malhotra',
#  'Atul Sabharwal',
#  'Audu Paden, Eric Radomski',
#  'August Jakobsson',
#  'Augustine Frizzell',
#  'Aurora Guerrero',
#  'Austin Peck, Anneliese Vandenberg',
#  'Austin Stark',
#  'Ava DuVernay',
#  'Avadhoot Gupte',
#  'Avgousta Zourelidi',
#  'Avi Federgreen',
#  'Avinash Arun',
#  'Avinash Das',
#  'Avinash Walzade',
#  'Awi Suryadi',
#  'Axelle Laffont',
#  'Ayaan Mukherji',
#  'Ayman Makram',
#  'Aytaç Ağırlar',
#  'Ayumu Watanabe',
#  'Ayush Raina',
#  'Azazel Jacobs',
#  'Azfar Jafri',
#  'Aziz Ansari',
#  'Aziz Mirza',
#  'B. Subhash',
#  'B. T Thomas',
#  'B. Unnikrishnan',
#  'B. V. Nandini Reddy',
#  'B.N. Shajeer Sha',
#  'BB Sasore',
#  'Babak Anvari',
#  'Bahij Hojeij',
#  'Baljit Singh Deo',
#  'Baltasar Kormákur',
#  'Balu Mahendra',
#  'Banjong Pisanthanakun',
#  'Banjong Pisanthanakun, Parkpoom Wongpoom',
#  'Banjong Pisanthanakun, Paween Purikitpanya, Songyos Sugmakanan, Parkpoom Wongpoom, Visute Poolvoralaks',
#  'Bao Nhan, Namcito',
#  'Barak Goodman',
#  'Baran bo Odar',
#  'Barbara Białowąs, Tomasz Mandes',
#  'Barbara Kopple',
#  'Barbra Streisand',
#  'Barbra Streisand, Jim Gable',
#  'Barney Clay',
#  'Barry Avrich',
#  'Barry Gonzalez',
#  'Barry Jenkins',
#  'Barry Levinson',
#  'Barry Sonnenfeld',
#  'Bart Freundlich',
#  'Bartosz M. Kowalski',
#  'Basava Shankar Eeday',
#  'Bashir El Deek',
#  'Bassam Kurdali',
#  'Bassam Tariq',
#  'Basu Chatterjee',
#  'Bauddhayan Mukherji',
#  'Baz Luhrmann',
#  'Bedabrata Pain',
#  'Bedran Güzel',
#  'Beeban Kidron',
#  'Bejoy Nambiar',
#  'Bejoy Nambiar, Priyadarshan, Karthik Narain, Vasanth Sai, Karthik Subbaraj, Arvind Swamy, Rathindran R Prasad, Sarjun, Gautham Vasudev Menon',
#  'Ben A. Williams',
#  'Ben Bowie, Geoff Luck',
#  'Ben Brewer, Alex Brewer',
#  'Ben C. Lucas',
#  'Ben Falcone',
#  'Ben Kasulke',
#  'Ben Palmer',
#  'Ben Patterson',
#  'Ben Ryder',
#  'Ben Shelton',
#  'Ben Simms',
#  'Ben Steele',
#  'Ben Wallis',
#  'Ben Wheatley',
#  'Ben Young',
#  'Ben Younger',
#  'Benedict Andrews',
#  'Benjamin Arfmann',
#  'Benjamin Cohen, Nicolas Cotto',
#  'Benjamin Dickinson',
#  'Benjamin Ree',
#  'Benjamin Ross',
#  'Benjamin Turner',
#  'Benjamin Turner, Gabe Turner',
#  'Benjamin Weill',
#  'Benny Fine',
#  'Benny Fredman',
#  'Benny Safdie, Josh Safdie',
#  'Benoît Jacquot',
#  'Benson Lee',
#  'Bent-Jorgen Perlmutt',
#  'Bernard Rose',
#  'Bernardo Arellano',
#  'Bernie Denk',
#  'Bert Marcus',
#  'Bert Marcus, Cyrus Saidi',
#  'Beth Sleven, Allan Jacobsen, Kevin Wotton',
#  'Bette Gordon',
#  'Betty Thomas',
#  'Beyoncé Knowles-Carter',
#  'Bhagyaraj',
#  'Bharat Jain',
#  'Bharat Nalluri',
#  'Bhavik Thakore',
#  'Bhavin Wadia',
#  'Bhushan Patel',
#  'Bigflo & Oli, Jérémie Levypon',
#  'Bilal Lashari',
#  'Bill Condon',
#  "Bill D'Elia",
#  'Bill Guttentag, Michael Ware',
#  'Bill Oliver',
#  'Bille August',
#  'Bille Woodruff',
#  'Billy Bob Thornton',
#  'Billy Corben',
#  'Billy Lyons',
#  'Billy Ray',
#  'Bin Bunluerit',
#  'Binayak Das',
#  'Binu Ulahhannan',
#  'Biodun Stephen',
#  'Biswajeet Bora',
#  'Biyi Bandele',
#  'Blair Hayes',
#  'Blair Simmons',
#  'Blake Harris, Chris Bouchard',
#  'Blayne Weaver',
#  'Bo Burnham',
#  'Bo Burnham, Christopher Storer',
#  'Bo Welch',
#  'Bob Hercules, Rita Coburn Whack',
#  'Bob Nelson',
#  'Bob Odenkirk',
#  'Bob Rose',
#  'Bobby Farrelly, Peter Farrelly',
#  'Bobby Roth',
#  'Bobcat Goldthwait',
#  'Bolanle Austen-Peters',
#  'Bong Joon Ho',
#  'Bonni Cohen, Jon Shenk',
#  'Borja Cobeaga',
#  'Brad Anderson',
#  'Brad Bird',
#  'Brad Furman',
#  'Brad Peyton',
#  'Brad Silberling',
#  'Braden R. Duemmler',
#  'Bradley Parker',
#  'Bradley Walsh',
#  'Brandon Camp',
#  'Brandon Dickerson',
#  'Brandon Jones',
#  'Brant Sersen',
#  'Brendan Byrne',
#  'Brendan Malloy, Emmett Malloy',
#  'Brendan Toller',
#  'Brendon Marotta',
#  'Brent Bonacorso',
#  'Brent Dawes',
#  'Brent Maddock',
#  'Brett Donowho',
#  'Brett Haley',
#  'Brett Harvey',
#  'Brett Hedlund',
#  'Brett Ratner',
#  'Brett Weiner',
#  'Brett Whitcomb',
#  'Brian A. Miller',
#  'Brian Andrew Mendoza',
#  'Brian Baugh',
#  'Brian De Palma',
#  'Brian Helgeland',
#  'Brian Henson',
#  'Brian Klein',
#  'Brian Knappenberger',
#  'Brian Levant',
#  'Brian M. Conley, Nathan Ives',
#  "Brian O'Malley",
#  'Brian Oakes',
#  'Brian Robbins',
#  'Brian Skiba',
#  'Brian Smith',
#  'Brian Smrz',
#  'Brian Volk-Weiss',
#  'Brian Webber',
#  'Brie Larson',
#  'Brit McAdams',
#  'Brittany Andrews',
#  'Brodje Wemboendja',
#  'Brody Chu',
#  'Bronwen Hughes',
#  'Bruce Beresford',
#  'Bruce Gowers',
#  'Bruce Leddy',
#  'Bruce MacDonald, Gabriel Sabloff',
#  'Bruce McCulloch',
#  'Bruce McDonald',
#  'Bruce Robinson',
#  'Bruce W. Smith',
#  'Bruno Garotti',
#  'Bryan Bertino',
#  'Bryan Buckley',
#  'Bryan Fogel',
#  'Bryan Singer',
#  'Bryce Wagoner',
#  'Bryn Evans',
#  'Buchi Babu Sana',
#  'Buddhadev Dasgupta',
#  'Bumpy',
#  'Bunmi Ajakaiye',
#  'Burak Aksak',
#  'Burhan Qurbani',
#  'Burr Steers',
#  'Buta Singh',
#  'Buz Wallick',
#  'Buzz Kulik',
#  'Byeon Hee-sun',
#  'Byron Howard, Chris Williams',
#  'Byun Hyuk',
#  'C. Fitz',
#  'C.J. Wallis',
#  'Cai Cong',
#  'Caio Cobra',
#  'Cal Brunker',
#  'Cal Saville',
#  'Cal Seville',
#  'Callie Khouri, Jesse V. Johnson',
#  'Camilla Nielsson',
#  'Camille Delamarre',
#  'Camille Shooshani',
#  'Can Ulkay',
#  'Caradog W. James',
#  'Carey McKenzie',
#  'Carla Barros',
#  'Carles Torras',
#  'Carlo Padial',
#  'Carlos Algara, Alejandro Martinez-Beltran',
#  'Carlos Bolado',
#  'Carlos Marques-Marcet',
#  'Carlos Moreno',
#  'Carlos Morett',
#  'Carlos Pérez Osorio',
#  'Carlos Sedes',
#  'Carlos Sorín',
#  'Carlos Therón',
#  'Carlos Vermut',
#  'Carly Stone',
#  'Caroline Suh',
#  'Cary Joji Fukunaga',
#  'Cary Murnion, Jonathan Milott',
#  'Caryn Waechter',
#  'Cassi Simonds',
#  'Cassia Dian',
#  'Castille Landon',
#  'Cate Shortland',
#  'Catherine Hardwicke',
#  'Cathy Garcia-Molina',
#  'Cavi Borges, Luciano Vidigal',
#  'Cecilia Atán, Valeria Pivato',
#  'Cecilia Peck',
#  'Cecilia Verheyden',
#  'Cedric Nicolas-Troyan',
#  'Cem Yılmaz',
#  'Chad Archibald',
#  'Chad Hartigan',
#  'Chad L. Scheifele',
#  'Chad Van De Keere',
#  'Chairun Nissa',
#  'Chaitanya Tamhane',
#  'Chakri Toleti',
#  'Chan-sang Lim',
#  'Chanda Bell',
#  'Chandan Arora',
#  'Chandra Liow',
#  'Chandra Prakash Dwivedi',
#  'Chandrakant Kanse',
#  'Chandrakant Kulkarni',
#  'Chandran Narikode',
#  'Chang Chin-jung, Chen Rong-hui',
#  'Chang-Min Lee',
#  'Chanon Yingyong, Phuwanit Pholdee',
#  'Chapman Way, Maclain Way',
#  'Charles A. Nichols, Iwao Takamoto',
#  'Charles Gozali, Bagus Bramanti',
#  'Charles Martin',
#  'Charles Martin Smith',
#  'Charles Officer',
#  'Charles Stone III',
#  'Charles Uwagbai',
#  'Charlie Haskell, Koichi Sakamoto',
#  'Charlie Kaufman',
#  'Charlie Lightening',
#  'Charlie McDowell',
#  'Charlie Siskel',
#  'Charlie Vaughn',
#  'Charlotte Zwerin',
#  'Charneice Fox',
#  'Chatchai Katenut, Manussa Vorasingha, Tanwarin Sukkhapisit, Poj Arnon',
#  'Chayanop Boonprakob',
#  'Che Sandoval',
#  'Cheang Pou Soi',
#  'Cheh Chang',
#  'Cheng Wei-hao',
#  'Chester Tam',
#  'Cheta Chukwu',
#  'Chi Fat Chan',
#  'Chi Keung Fung',
#  'Chia Tang',
#  'Chia-Liang Liu',
#  'Chiaki Kon',
#  'Chinaza Onuzo',
#  'Chineze Anyaene',
#  'Chito S. Roño',
#  'Chiwetel Ejiofor',
#  'Cho Il',
#  'Cho Li, Chen Hung-yi, Weica Wang, Liu Bang-yao, Lin Guan-fu, Shen Chi, YC Tom Lee',
#  'Choi Jin-seong',
#  'Chow Hin Yeung Roy',
#  'Chris Appelhans',
#  'Chris Baugh',
#  'Chris Bell',
#  'Chris Bell, Josh Alexander, Greg Young',
#  'Chris Blake',
#  'Chris Bolan',
#  'Chris Bould',
#  'Chris Buck, Jennifer Lee, Patrick Osborne, Lauren MacMullan, John Kahrs, Nathan Greno, Byron Howard, Stevie Wermers, Dean Wellins, Kevin Deters, Roger Allers, Mike Gabriel, Mark Henn',
#  'Chris Buck, Kevin Lima',
#  'Chris Burkard',
#  'Chris Columbus',
#  'Chris Eigeman',
#  'Chris Eneng Enaji',
#  'Chris Foggin',
#  'Chris Gorak',
#  'Chris Howe',
#  'Chris Jenkins',
#  'Chris Kelly',
#  'Chris Koch',
#  'Chris McCoy',
#  'Chris Miller',
#  'Chris Moukarbel',
#  'Chris Nahon',
#  'Chris Nelson',
#  'Chris Perkel',
#  'Chris Renaud',
#  'Chris Renaud, Kyle Balda',
#  'Chris Robinson',
#  'Chris Rock',
#  'Chris Roland, Maradona Dias Dos Santos',
#  'Chris Sivertson',
#  'Chris Smith',
#  'Chris Sparling',
#  'Chris Stokes',
#  'Chris Weitz',
#  'Chris Weitz, Paul Weitz',
#  'Christel Gibson',
#  'Christian Alvart',
#  'Christian Charles',
#  'Christian De Vita',
#  'Christian Desmares, Franck Ekinci',
#  'Christian Ditter',
#  'Christian Duguay',
#  'Christian E. Christiansen',
#  'Christian Gudegast',
#  'Christian Schwochow',
#  'Christian Zübert',
#  'Christine Luby',
#  'Christophe Charrier',
#  'Christophe Honoré',
#  'Christopher Alender',
#  'Christopher Amos',
#  'Christopher Cain',
#  'Christopher Chambers',
#  'Christopher Guest',
#  'Christopher Louie',
#  'Christopher Martin',
#  'Christopher Murray',
#  'Christopher Nolan',
#  'Christopher Nolen',
#  'Christopher Ray',
#  'Christopher S. Rech, Brandon Kimber',
#  'Christopher Smith',
#  'Christopher Storer',
#  'Chuck Russell',
#  'Chun Wong',
#  'Chung Mong-hong',
#  'Ciarán Foy',
#  'Claire McCarthy',
#  'Claire Scanlon',
#  'Clara Martínez-Lázaro',
#  'Clarence Yiu-leung Fok',
#  'Clark Johnson',
#  'Claude Barras',
#  'Claude Lelouch',
#  'Clay Glen',
#  'Clay Kaytis',
#  'Clay Porter',
#  'Clay Staub',
#  'Clementine Malpas, Leslie Knott',
#  'Clint Butler',
#  'Clint Eastwood',
#  'Clive Tonge',
#  'Clovis Cornillac',
#  'Cody Cameron, Kris Pearn',
#  'Cody Stokes',
#  'Coerte Voorhees, John Voorhees',
#  'Colin Dench',
#  'Colin Minihan',
#  'Colin Strause, Greg Strause',
#  'Colin Teague',
#  'Colin Trevorrow',
#  'Conor Allyn',
#  'Conrad Helten',
#  'Conrad Helten, Ezekiel Norton, Michael Goguen',
#  'Constance Marks',
#  'Coodie, Chike',
#  'Cooper Karl',
#  'Corbin Bernsen',
#  'Corey Grant',
#  'Corey Yuen',
#  'Corey Yuen, Patrick Leung',
#  'Cory Edwards',
#  'Cosima Spender',
#  'Cosmo Feilding-Mellen',
#  'Courtney Hunt',
#  'Craig Anderson',
#  'Craig Brewer',
#  'Craig Elrod',
#  'Craig Freimond',
#  'Craig Gillespie',
#  'Craig Goodwill',
#  'Craig Johnson',
#  'Craig Moss',
#  "Cris D'Amato",
#  'Cristi Puiu',
#  'Cristina Costantini, Kareem Tabsch',
#  'Cristina Jacob',
#  'Crystal Moselle',
#  'Curro Velázquez',
#  'Curtis Graham',
#  'Curtis Hanson',
#  'Cyrus Nowrasteh',
#  'Cédric Jimenez',
#  'Célia Catunda, Kiko Mistrorigo, Rodrigo Eba',
#  'César Rodrigues',
#  'Cüneyt Kaya',
#  'D Ho',
#  'DJ Chen',
#  'Daan Jansen, Stijn Verlinde',
#  'Dado C. Lumibao',
#  'Dallas Jackson',
#  'Dallas Jenkins',
#  'Damani Baker',
#  'Damien Chazelle, Houda Benyamina, Laïla Marrakchi, Alan Poul',
#  'Damien Leone',
#  'Damien O’Connor',
#  'Damien Piscarel, Florent Bodin',
#  'Damián Romay',
#  'Damon Cardasis',
#  'Dan Forgione, Pete Jacobs, Matt Whitlock',
#  'Dan Forrer',
#  'Dan Fraga, William Lau',
#  'Dan Gilroy',
#  'Dan Harris',
#  'Dan Krauss',
#  'Dan Kwan, Daniel Scheinert',
#  'Dan Lucchesi',
#  'Dan Villegas',
#  'Dana Doron, Uriel Sinai',
#  'Dana Nachman, Don Hardy Jr.',
#  'Dani Levy',
#  'Dani de la Orden',
#  'Dani de la Torre',
#  'Daniel Ablin',
#  'Daniel Alfredson',
#  'Daniel Arasanz',
#  'Daniel Benmayor',
#  'Daniel Burman',
#  'Daniel Calparsoro',
#  'Daniel Effiong',
#  'Daniel Espinosa',
#  'Daniel Goldhaber',
#  'Daniel Gordon',
#  'Daniel Gray Longino',
#  'Daniel J. Clark',
#  'Daniel Joseph',
#  'Daniel Kontur',
#  'Daniel Lee',
#  'Daniel Lindsay, T.J. Martin',
#  'Daniel Mann',
#  'Daniel Mann, Joseph Sargent',
#  'Daniel Markowicz',
#  'Daniel McCabe',
#  'Daniel Minahan',
#  'Daniel Monzón',
#  'Daniel Noah',
#  'Daniel Oriahi',
#  'Daniel Prochaska',
#  'Daniel Raim',
#  'Daniel Růžička',
#  'Daniel Sandu',
#  'Daniel Schechter',
#  'Daniel Stamm',
#  'Daniel Sánchez Arévalo',
#  'Daniel Vernon',
#  'Daniel Wilner',
#  'Daniel Yee Heng Chan',
#  'Daniela Goggi',
#  'Daniele Thompson',
#  'Danish Aslam',
#  'Danishka Esterhazy',
#  'Danny Boyle',
#  'Danny Cannon',
#  'Danny J. Boyle',
#  'Danny Leiner',
#  'Dante Lam',
#  'Dar Gai',
#  'Dare Olaitan',
#  "Darragh O'Connell",
#  'Darren Grant',
#  'Darren Lynn Bousman',
#  'Daryl Hannah',
#  'Dash Shaw',
#  'Datta Mohan Bhandare',
#  'Dava Whisenant',
#  'Dave Green',
#  'Dave Higby',
#  'Dave Needham',
#  'Dave Patten',
#  'Dave Skinner, Freddie Waters',
#  "David 'Tosh' Gitonga, Michael Jones",
#  'David A. Vargas',
#  'David Allensworth, Monière',
#  'David Ayer',
#  'David Batra, Jon Rudberg',
#  'David Batty',
#  'David Benioff, D.B. Weiss',
#  'David Benullo',
#  'David Blair',
#  'David Briggs',
#  'David Bruckner',
#  'David Charhon',
#  'David Chirchirillo',
#  'David Chuang, Chen Kuan-chung',
#  'David Cronenberg',
#  'David Dhawan',
#  'David Dobkin',
#  'David E. Talbert',
#  'David Fairhead',
#  'David Fairhead, Anthony Palmer',
#  'David Feiss',
#  'David Fincher',
#  'David France',
#  'David Frankel',
#  'David Galán Galindo',
#  'David Gelb',
#  'David Gordon Green',
#  'David Grossman',
#  'David Guy Levy',
#  'David Hackl',
#  'David Hunt',
#  'David Koepp',
#  'David L. Cunningham',
#  'David L.G. Hughes',
#  'David LaChapelle',
#  'David Lam',
#  'David Lean',
#  'David Lee Miller',
#  'David Leveaux',
#  'David Lowery',
#  'David Lynch',
#  'David M. Rosenthal',
#  ...]

# %%
# ensure consistent formatting

df['director'] = df['director'].str.strip().str.title()

# %%
df.isnull().sum()
# Out:
# type                0
# title               0
# director            0
# cast              825
# country           830
# date_added          0
# release_year        0
# rating              4
# listed_in           0
# description         0
# duration_value      3
# duration_unit       3
# dtype: int64

# %%
# format the 'cast' column, fill empty rows with 'unknown'

df['cast']=df['cast'].fillna('Unknown')

# %%
# make sure there are no whitespaces around names where there are multiple names in a cell

df['cast']=df['cast'].apply(lambda x: ','.join([name.strip() for name in x.split(',')]) if x!='Unknown' else x)

# %%
df['cast'].head(10)
# Out:
# 0                                              Unknown
# 1    Ama Qamata,Khosi Ngema,Gail Mabalane,Thabang M...
# 2    Sami Bouajila,Tracy Gotoas,Samuel Jouy,Nabiha ...
# 3                                              Unknown
# 4    Mayur More,Jitendra Kumar,Ranjan Raj,Alam Khan...
# 5    Kate Siegel,Zach Gilford,Hamish Linklater,Henr...
# 6    Vanessa Hudgens,Kimiko Glenn,James Marsden,Sof...
# 7    Kofi Ghanaba,Oyafunmike Ogunlano,Alexandra Dua...
# 8    Mel Giedroyc,Sue Perkins,Mary Berry,Paul Holly...
# 9    Melissa McCarthy,Chris O'Dowd,Kevin Kline,Timo...
# Name: cast, dtype: object

# %%
# find bad spacing

bad_cast_rows = df[df['cast'].apply(lambda x: any(name != name.strip() for name in x.split(',')) if x != 'Unknown' else False)]

print(len(bad_cast_rows))
bad_cast_rows.head()
# Out:
# 0
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, listed_in, description, duration_value, duration_unit]
# Index: []

# %%
# check for lowercase entries

df[df['cast'].str.match(r'^[a-z ,]+$') & (df['cast'] != 'Unknown')].head()
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, listed_in, description, duration_value, duration_unit]
# Index: []

# %%
df.isnull().sum()
# Out:
# type                0
# title               0
# director            0
# cast                0
# country           830
# date_added          0
# release_year        0
# rating              4
# listed_in           0
# description         0
# duration_value      3
# duration_unit       3
# dtype: int64

# %%
# fill empty 'country' rows with 'unknown'

df['country'] = df['country'].fillna('Unknown')

# %%
# trim extra spaces

df['country'] = df['country'].str.strip()

# %%
# ensure that all cells are capitalized correctly

df['country'] = df['country'].apply(
    lambda x: ', '.join([c.strip().title() for c in x.split(',')]) if x != 'Unknown' else x
)

# %%
# check for inconsistencies

df['country'].value_counts().head(30)
# Out:
# country
# United States                    2812
# India                             972
# Unknown                           830
# United Kingdom                    418
# Japan                             244
# South Korea                       199
# Canada                            181
# Spain                             145
# France                            124
# Mexico                            110
# Egypt                             106
# Turkey                            105
# Nigeria                            95
# Australia                          86
# Taiwan                             81
# Indonesia                          79
# Brazil                             77
# Philippines                        75
# United Kingdom, United States      75
# United States, Canada              73
# Germany                            67
# China                              66
# Thailand                           61
# Argentina                          56
# Hong Kong                          53
# United States, United Kingdom      47
# Italy                              45
# Canada, United States              45
# Colombia                           35
# South Africa                       30
# Name: count, dtype: int64

# %%
#create column for rows with multiple countries

df['country_count'] = df['country'].apply(lambda x: 0 if x == 'Unknown' else len(x.split(',')))

# %%
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water          Unknown
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans          Unknown
# 4  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata,Khosi Ngema,Gail Mabalane,Thabang M...   South Africa
# 2  Sami Bouajila,Tracy Gotoas,Samuel Jouy,Nabiha ...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More,Jitendra Kumar,Ranjan Raj,Alam Khan...          India
#
#            date_added  release_year rating  \
# 0  September 25, 2021          2020  PG-13
# 1  September 24, 2021          2021  TV-MA
# 2  September 24, 2021          2021  TV-MA
# 3  September 24, 2021          2021  TV-MA
# 4  September 24, 2021          2021  TV-MA
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  duration_value  \
# 0  As her father nears the end of his life, filmm...            90.0
# 1  After crossing paths at a party, a Cape Town t...             2.0
# 2  To protect his family from a powerful drug lor...             1.0
# 3  Feuds, flirtations and toilet talk go down amo...             1.0
# 4  In a city of coaching centers known to train I...             2.0
#
#   duration_unit  country_count
# 0           min              1
# 1       Seasons              1
# 2        Season              0
# 3        Season              0
# 4       Seasons              1

# %%
df.isnull().sum()
# Out:
# type              0
# title             0
# director          0
# cast              0
# country           0
# date_added        0
# release_year      0
# rating            4
# listed_in         0
# description       0
# duration_value    3
# duration_unit     3
# country_count     0
# dtype: int64

# %%
# drop rows with null values that are left

df.dropna(subset=['rating', 'duration_value', 'duration_unit'], inplace=True)

# %%
# convert to datetime format

df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
#check for any missing values in date or any broken formats

df[df['date_added'].isna()]
# Out:
#          type                        title                 director  \
# 6079  TV Show              Abnormal Summit  Jung-Ah Im, Seung-Uk Jo
# 6177  TV Show                     忍者ハットリくん                  Unknown
# 6213  TV Show                Bad Education                  Unknown
# 6279  TV Show  Being Mary Jane: The Series                  Unknown
# 6304  TV Show     Big Dreams, Small Spaces                  Unknown
# ...       ...                          ...                      ...
# 8539  TV Show                   The Tudors                  Unknown
# 8557  TV Show                The West Wing                  Unknown
# 8684  TV Show                      Vroomiz                  Unknown
# 8712  TV Show   Weird Wonders of the World                  Unknown
# 8755  TV Show            Women Behind Bars                  Unknown
#
#                                                    cast  \
# 6079             Hyun-moo Jun,Si-kyung Sung,Se-yoon Yoo
# 6177                                            Unknown
# 6213  Jack Whitehall,Mathew Horne,Sarah Solemani,Mic...
# 6279  Gabrielle Union,Lisa Vidal,Margaret Avery,Omar...
# 6304                                          Monty Don
# ...                                                 ...
# 8539  Jonathan Rhys Meyers,Henry Cavill,James Frain,...
# 8557  Martin Sheen,Rob Lowe,Allison Janney,John Spen...
# 8684  Joon-seok Song,Jeong-hwa Yang,Sang-hyun Um,So-...
# 8712                                      Chris Packham
# 8755                                            Unknown
#
#                                              country date_added  release_year  \
# 6079                                     South Korea        NaT          2017
# 6177                                           Japan        NaT          2012
# 6213                                  United Kingdom        NaT          2014
# 6279                                   United States        NaT          2016
# 6304                                  United Kingdom        NaT          2017
# ...                                              ...        ...           ...
# 8539  Ireland, Canada, United States, United Kingdom        NaT          2010
# 8557                                   United States        NaT          2005
# 8684                                     South Korea        NaT          2016
# 8712                                  United Kingdom        NaT          2016
# 8755                                   United States        NaT          2010
#
#      rating                                          listed_in  \
# 6079  TV-PG  International TV Shows, Korean TV Shows, Stand...
# 6177  TV-Y7                             Anime Series, Kids' TV
# 6213  TV-MA                      British TV Shows, TV Comedies
# 6279  TV-14                       Romantic TV Shows, TV Dramas
# 6304   TV-G  British TV Shows, International TV Shows, Real...
# ...     ...                                                ...
# 8539  TV-MA                                          TV Dramas
# 8557  TV-14                                          TV Dramas
# 8684   TV-Y                          Kids' TV, Korean TV Shows
# 8712  TV-PG  British TV Shows, Docuseries, Science & Nature TV
# 8755  TV-14                         Crime TV Shows, Docuseries
#
#                                             description  duration_value  \
# 6079  Led by a trio of Korean celebs, a multinationa...             2.0
# 6177  Hailing from the mountains of Iga, Kanzo Hatto...             2.0
# 6213  A history teacher at the posh Abbey Grove, Alf...             3.0
# 6279  Ambitious single TV journalist Mary Jane attem...             4.0
# 6304  Writer and presenter Monty Don helps England's...             3.0
# ...                                                 ...             ...
# 8539  All the splendor and scandal of England's 16th...             4.0
# 8557  This powerful political epic chronicles the tr...             7.0
# 8684  For these half-car, half-animal friends, each ...             3.0
# 8712  From animal oddities and bizarre science to me...             2.0
# 8755  This reality series recounts true stories of w...             3.0
#
#      duration_unit  country_count
# 6079       Seasons              1
# 6177       Seasons              1
# 6213       Seasons              1
# 6279       Seasons              1
# 6304       Seasons              1
# ...            ...            ...
# 8539       Seasons              4
# 8557       Seasons              1
# 8684       Seasons              1
# 8712       Seasons              1
# 8755       Seasons              1
#
# [88 rows x 13 columns]

# %%
# check what is causing the problem in dates

data[data['date_added'].isna()][['date_added']]
# Out:
#      date_added
# 6066        NaN
# 6174        NaN
# 6795        NaN
# 6806        NaN
# 6901        NaN
# 7196        NaN
# 7254        NaN
# 7406        NaN
# 7847        NaN
# 8182        NaN

# %%
# the NaT rows were caused by missing values so these rows will be dropped (only keep rows that don't have missing values)

df = df[~df['date_added'].isna()]

# %%
# confirm that date column is now clean

print(df['date_added'].isna().sum())
# Out:
# 0

# %%
# check for any duplicate rows

print("Original duplicates:", df.duplicated().sum())
# Out:
# Original duplicates: 0

# %% [markdown]
# # Create seperate dataframes for movies and TV shows

# %%
df_mov = df[df['type'] == 'Movie'].copy()
df_tv = df[df['type'] == 'TV Show'].copy()

# %%
# re-check for duplicates

print("Movie duplicates after split:", df_mov.duplicated().sum())
print("TV Show duplicates after split:", df_tv.duplicated().sum())
# Out:
# Movie duplicates after split: 0
# TV Show duplicates after split: 0

# %% [markdown]
# # Final check for Movies and TV Shows cleanup

# %%
# check if all duration values are whole numbers(integers)

is_whole_numbers = df_mov['duration_value'].apply(lambda x: float(x).is_integer()).all()

print(is_whole_numbers)
# Out:
# True

# %%
is_whole_numbers = df_tv['duration_value'].apply(lambda x: float(x).is_integer()).all()

print(is_whole_numbers)
# Out:
# True

# %%
# change type to integer from float
df_mov['duration_value'] = df_mov['duration_value'].astype(int)

# %%
df_tv['duration_value'] = df_tv['duration_value'].astype(int)

# %%
df_tv
# Out:
#          type                  title         director  \
# 1     TV Show          Blood & Water          Unknown
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans          Unknown
# 4     TV Show           Kota Factory          Unknown
# 5     TV Show          Midnight Mass    Mike Flanagan
# ...       ...                    ...              ...
# 8795  TV Show        Yu-Gi-Oh! Arc-V          Unknown
# 8796  TV Show             Yunus Emre          Unknown
# 8797  TV Show              Zak Storm          Unknown
# 8800  TV Show     Zindagi Gulzar Hai          Unknown
# 8803  TV Show            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata,Khosi Ngema,Gail Mabalane,Thabang M...
# 2     Sami Bouajila,Tracy Gotoas,Samuel Jouy,Nabiha ...
# 3                                               Unknown
# 4     Mayur More,Jitendra Kumar,Ranjan Raj,Alam Khan...
# 5     Kate Siegel,Zach Gilford,Hamish Linklater,Henr...
# ...                                                 ...
# 8795  Mike Liscio,Emily Bauer,Billy Bob Thompson,Aly...
# 8796  Gökhan Atalay,Payidar Tüfekçioglu,Baran Akbulu...
# 8797  Michael Johnston,Jessica Gee-George,Christine ...
# 8800  Sanam Saeed,Fawad Khan,Ayesha Omer,Mehreen Rah...
# 8803                                            Unknown
#
#                                             country date_added  release_year  \
# 1                                      South Africa 2021-09-24          2021
# 2                                           Unknown 2021-09-24          2021
# 3                                           Unknown 2021-09-24          2021
# 4                                             India 2021-09-24          2021
# 5                                           Unknown 2021-09-24          2021
# ...                                             ...        ...           ...
# 8795                                  Japan, Canada 2018-05-01          2015
# 8796                                         Turkey 2017-01-17          2016
# 8797  United States, France, South Korea, Indonesia 2018-09-13          2016
# 8800                                       Pakistan 2016-12-15          2012
# 8803                                        Unknown 2019-07-01          2018
#
#      rating                                          listed_in  \
# 1     TV-MA    International TV Shows, TV Dramas, TV Mysteries
# 2     TV-MA  Crime TV Shows, International TV Shows, TV Act...
# 3     TV-MA                             Docuseries, Reality TV
# 4     TV-MA  International TV Shows, Romantic TV Shows, TV ...
# 5     TV-MA                 TV Dramas, TV Horror, TV Mysteries
# ...     ...                                                ...
# 8795  TV-Y7                             Anime Series, Kids' TV
# 8796  TV-PG                  International TV Shows, TV Dramas
# 8797  TV-Y7                                           Kids' TV
# 8800  TV-PG  International TV Shows, Romantic TV Shows, TV ...
# 8803  TV-Y7             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description  duration_value  \
# 1     After crossing paths at a party, a Cape Town t...               2
# 2     To protect his family from a powerful drug lor...               1
# 3     Feuds, flirtations and toilet talk go down amo...               1
# 4     In a city of coaching centers known to train I...               2
# 5     The arrival of a charismatic young priest brin...               1
# ...                                                 ...             ...
# 8795  Now that he's discovered the Pendulum Summonin...               2
# 8796  During the Mongol invasions, Yunus Emre leaves...               2
# 8797  Teen surfer Zak Storm is mysteriously transpor...               3
# 8800  Strong-willed, middle-class Kashaf and carefre...               1
# 8803  While living alone in a spooky town, a young g...               2
#
#      duration_unit  country_count
# 1          Seasons              1
# 2           Season              0
# 3           Season              0
# 4          Seasons              1
# 5           Season              0
# ...            ...            ...
# 8795       Seasons              2
# 8796       Seasons              1
# 8797       Seasons              4
# 8800        Season              1
# 8803       Seasons              0
#
# [2576 rows x 13 columns]

# %% [markdown]
# # Export to .csv files

# %%
df_mov.to_csv('movies_data.csv', sep=';', index=False)

# %%
df_tv.to_csv('tv_data.csv', sep=';', index=False)

# %%
# concat a third csv file to use for combined chart

full_df = pd.concat([df_mov, df_tv], ignore_index=True)

# %%
full_df
# Out:
#          type                             title  \
# 0       Movie              Dick Johnson Is Dead
# 1       Movie  My Little Pony: A New Generation
# 2       Movie                           Sankofa
# 3       Movie                      The Starling
# 4       Movie                      Je Suis Karl
# ...       ...                               ...
# 8697  TV Show                   Yu-Gi-Oh! Arc-V
# 8698  TV Show                        Yunus Emre
# 8699  TV Show                         Zak Storm
# 8700  TV Show                Zindagi Gulzar Hai
# 8701  TV Show                       Zombie Dumb
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 8697                        Unknown
# 8698                        Unknown
# 8699                        Unknown
# 8700                        Unknown
# 8701                        Unknown
#
#                                                    cast  \
# 0                                               Unknown
# 1     Vanessa Hudgens,Kimiko Glenn,James Marsden,Sof...
# 2     Kofi Ghanaba,Oyafunmike Ogunlano,Alexandra Dua...
# 3     Melissa McCarthy,Chris O'Dowd,Kevin Kline,Timo...
# 4     Luna Wedler,Jannis Niewöhner,Milan Peschel,Edi...
# ...                                                 ...
# 8697  Mike Liscio,Emily Bauer,Billy Bob Thompson,Aly...
# 8698  Gökhan Atalay,Payidar Tüfekçioglu,Baran Akbulu...
# 8699  Michael Johnston,Jessica Gee-George,Christine ...
# 8700  Sanam Saeed,Fawad Khan,Ayesha Omer,Mehreen Rah...
# 8701                                            Unknown
#
#                                                 country date_added  \
# 0                                         United States 2021-09-25
# 1                                               Unknown 2021-09-24
# 2     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 3                                         United States 2021-09-24
# 4                               Germany, Czech Republic 2021-09-23
# ...                                                 ...        ...
# 8697                                      Japan, Canada 2018-05-01
# 8698                                             Turkey 2017-01-17
# 8699      United States, France, South Korea, Indonesia 2018-09-13
# 8700                                           Pakistan 2016-12-15
# 8701                                            Unknown 2019-07-01
#
#       release_year rating                                          listed_in  \
# 0             2020  PG-13                                      Documentaries
# 1             2021     PG                           Children & Family Movies
# 2             1993  TV-MA   Dramas, Independent Movies, International Movies
# 3             2021  PG-13                                   Comedies, Dramas
# 4             2021  TV-MA                       Dramas, International Movies
# ...            ...    ...                                                ...
# 8697          2015  TV-Y7                             Anime Series, Kids' TV
# 8698          2016  TV-PG                  International TV Shows, TV Dramas
# 8699          2016  TV-Y7                                           Kids' TV
# 8700          2012  TV-PG  International TV Shows, Romantic TV Shows, TV ...
# 8701          2018  TV-Y7             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description  duration_value  \
# 0     As her father nears the end of his life, filmm...              90
# 1     Equestria's divided. But a bright-eyed hero be...              91
# 2     On a photo shoot in Ghana, an American model s...             125
# 3     A woman adjusting to life after a loss contend...             104
# 4     After most of her family is murdered in a terr...             127
# ...                                                 ...             ...
# 8697  Now that he's discovered the Pendulum Summonin...               2
# 8698  During the Mongol invasions, Yunus Emre leaves...               2
# 8699  Teen surfer Zak Storm is mysteriously transpor...               3
# 8700  Strong-willed, middle-class Kashaf and carefre...               1
# 8701  While living alone in a spooky town, a young g...               2
#
#      duration_unit  country_count
# 0              min              1
# 1              min              0
# 2              min              6
# 3              min              1
# 4              min              2
# ...            ...            ...
# 8697       Seasons              2
# 8698       Seasons              1
# 8699       Seasons              4
# 8700        Season              1
# 8701       Seasons              0
#
# [8702 rows x 13 columns]

# %%
full_df.to_csv('netflix_data.csv', sep=';', index=False)
